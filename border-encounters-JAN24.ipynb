# %% [markdown]
# ## Southwest border encounters by state
#
# States comprising southwest land border:
#
# * Texas
# * New Mexico
# * Arizona
# * California

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('data/nationwide-encounters-fy20-fy23-state.csv')

# %% [markdown]
# We need to separately load data from current fiscal year and append

# %%
df2 = pd.read_csv('data/nationwide-encounters-fy21-fy24-jan-state.csv')

# %% [markdown]
# We only need Jan, as the most recent month's data includes all previous months

# %%
# We only need to keep the 2024 fiscal year from df2
df2 = df2[df2['Fiscal Year'] == '2024 (FYTD)']

# %%
df2.head()
# Out:
#        Fiscal Year Month Grouping Month (abbv)    Land Border Region State  \
# 34588  2024 (FYTD)           FYTD          DEC  Northern Land Border    AK
# 34589  2024 (FYTD)           FYTD          DEC  Northern Land Border    AK
# 34590  2024 (FYTD)           FYTD          DEC  Northern Land Border    AK
# 34591  2024 (FYTD)           FYTD          DEC  Northern Land Border    AK
# 34592  2024 (FYTD)           FYTD          DEC  Northern Land Border    AK
#
#          Demographic                 Citizenship Title of Authority  \
# 34588  Single Adults                      CANADA            Title 8
# 34589  Single Adults  CHINA, PEOPLES REPUBLIC OF            Title 8
# 34590  Single Adults                       INDIA            Title 8
# 34591  Single Adults                       OTHER            Title 8
# 34592  Single Adults                 PHILIPPINES            Title 8
#
#        Encounter Count
# 34588                1
# 34589                2
# 34590                1
# 34591                6
# 34592                7

# %%
df2.tail()
# Out:
#        Fiscal Year Month Grouping Month (abbv)     Land Border Region State  \
# 38661  2024 (FYTD)           FYTD          OCT  Southwest Land Border    TX
# 38662  2024 (FYTD)           FYTD          OCT  Southwest Land Border    TX
# 38663  2024 (FYTD)           FYTD          OCT  Southwest Land Border    TX
# 38664  2024 (FYTD)           FYTD          OCT  Southwest Land Border    TX
# 38665  2024 (FYTD)           FYTD          OCT  Southwest Land Border    TX
#
#               Demographic Citizenship Title of Authority  Encounter Count
# 38661  UC / Single Minors       OTHER            Title 8               18
# 38662  UC / Single Minors        PERU            Title 8                8
# 38663  UC / Single Minors      RUSSIA            Title 8                5
# 38664  UC / Single Minors      TURKEY            Title 8                1
# 38665  UC / Single Minors   VENEZUELA            Title 8              442

# %%
# Then change it to just the number 2024
df2['Fiscal Year'] = 2024

# %%
# And append to main dataframe
df = pd.concat([df1, df2], axis=0)

# %%
df.tail()
# Out:
#        Fiscal Year Month Grouping Month (abbv)     Land Border Region State  \
# 38661         2024           FYTD          OCT  Southwest Land Border    TX
# 38662         2024           FYTD          OCT  Southwest Land Border    TX
# 38663         2024           FYTD          OCT  Southwest Land Border    TX
# 38664         2024           FYTD          OCT  Southwest Land Border    TX
# 38665         2024           FYTD          OCT  Southwest Land Border    TX
#
#               Demographic Citizenship Title of Authority  Encounter Count
# 38661  UC / Single Minors       OTHER            Title 8               18
# 38662  UC / Single Minors        PERU            Title 8                8
# 38663  UC / Single Minors      RUSSIA            Title 8                5
# 38664  UC / Single Minors      TURKEY            Title 8                1
# 38665  UC / Single Minors   VENEZUELA            Title 8              442

# %% [markdown]
# We start with a big dataframe with an individual record for each encounters per month, state, authority, citizenship etc.
#
# To make the chart we want to group all of these records by year, state and month, and then sum the number of encounters.
#
# Let's start by making a column that combines year and month.

# %%
# First combine the columns
df['Fiscal Year'].astype('str') + '-' + df['Month (abbv)']
# Out:
# 0        2020-APR
# 1        2020-APR
# 2        2020-APR
# 3        2020-APR
# 4        2020-APR
#            ...
# 38661    2024-OCT
# 38662    2024-OCT
# 38663    2024-OCT
# 38664    2024-OCT
# 38665    2024-OCT
# Length: 46610, dtype: object

# %%
# Then make a new column for numerical year-month
df['Date'] = pd.to_datetime(df['Fiscal Year'].astype('str') + '-' + df['Month (abbv)'], format='%Y-%b').dt.strftime('%Y-%m')

# %%
df.head()
# Out:
#    Fiscal Year Month Grouping Month (abbv)    Land Border Region State  \
# 0         2020           FYTD          APR  Northern Land Border    ID
# 1         2020           FYTD          APR  Northern Land Border    ME
# 2         2020           FYTD          APR  Northern Land Border    ME
# 3         2020           FYTD          APR  Northern Land Border    ME
# 4         2020           FYTD          APR  Northern Land Border    ME
#
#      Demographic                 Citizenship Title of Authority  \
# 0  Single Adults                      CANADA            Title 8
# 1  Single Adults                      CANADA           Title 42
# 2  Single Adults                      CANADA            Title 8
# 3  Single Adults  CHINA, PEOPLES REPUBLIC OF           Title 42
# 4  Single Adults  CHINA, PEOPLES REPUBLIC OF            Title 8
#
#    Encounter Count     Date
# 0                2  2020-04
# 1                2  2020-04
# 2              153  2020-04
# 3                1  2020-04
# 4                0  2020-04

# %% [markdown]
# Now we select only the southwest land border states:

# %%
states = ['TX', 'CA', 'NM', 'AZ']

# %%
# New dataframe with states in that list
dfs = df[df.State.isin(states)]

# %%
dfs.groupby(['State', 'Fiscal Year','Month (abbv)'])['Encounter Count'].sum()
# Out:
# State  Fiscal Year  Month (abbv)
# AZ     2020         APR               2991
#                     AUG               7656
#                     DEC               8388
#                     FEB               7185
#                     JAN               6771
#                                      ...
# TX     2023         SEP             161356
#        2024         DEC             155737
#                     JAN              73750
#                     NOV             116664
#                     OCT             125862
# Name: Encounter Count, Length: 208, dtype: int64

# %% [markdown]
# Make a pivot table: we want to index by Date, and have a column for each state with a sum of encounters.

# %%
dfs.pivot_table(index='Date', columns='State', values='Encounter Count', aggfunc='sum')
# Out:
# State       AZ     CA     NM      TX
# Date
# 2020-01   6771   9828   1167   23119
# 2020-02   7185  10317   1128   22151
# 2020-03   6254  10598   1411   22723
# 2020-04   2991   5661   1137   15818
# 2020-05   3922   7683   1974   18492
# 2020-06   5851  10322   2792   22258
# 2020-07   6530  12475   3717   23484
# 2020-08   7656  13433   4749   30284
# 2020-09   9315  12302   5859   36451
# 2020-10   8518   9903   1712   29399
# 2020-11   8644   9679   1250   26953
# 2020-12   8388   9969   1115   25320
# 2021-01  12597  16143   6734   49855
# 2021-02  20157  17292   7416   61576
# 2021-03  32068  23718   9794  114184
# 2021-04  34423  26567  12214  112640
# 2021-05  32773  27817  15302  111453
# 2021-06  31858  27985  14544  121589
# 2021-07  34067  28146  13240  145223
# 2021-08  34992  26166  14127  141498
# 2021-09  40573  23512  12539  122398
# 2021-10  12543  14151   6073   45709
# 2021-11  13407  14438   5971   44388
# 2021-12  12598  14387   7676   45393
# 2022-01  42094  22607   9608   88789
# 2022-02  42700  24271  10790   95926
# 2022-03  58879  33306  13916  125564
# 2022-04  54892  46071  13947  128836
# 2022-05  61385  34209  13003  141571
# 2022-06  44605  29020  13789  129269
# 2022-07  42123  31340  12847  120957
# 2022-08  43825  31974  14429  123016
# 2022-09  48601  34952  12199  140878
# 2022-10  41419  25578   9699   95822
# 2022-11  45128  23986   9714  103457
# 2022-12  46069  24978   9916  105705
# 2023-01  33415  31304  16675   85118
# 2023-02  35879  31071  20783   77412
# 2023-03  49400  39489  25186   89012
# 2023-04  49511  40102  21160  110702
# 2023-05  48186  39915  14489  114275
# 2023-06  36259  30596  10354   76658
# 2023-07  49203  34390   9971   98834
# 2023-08  59589  39239  11759  132257
# 2023-09  61471  47256   9215  161356
# 2023-10  49442  37797  10536  142636
# 2023-11  49842  36713  10570  147541
# 2023-12  54704  42669  10154  154913
# 2024-01  58322  44250   8298   73750
# 2024-10  65246  51516   8119  125862
# 2024-11  74816  51515   8079  116664
# 2024-12  91354  55774   8414  155737

# %%
# Assign pivot table to a variable
dfpiv = dfs.pivot_table(index='Date', columns='State', values='Encounter Count', aggfunc='sum')

# %%
dfpiv.plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# The chart above has big jumps because we actually need to order months by fiscal year, not by calendar order.
#
# Some tips on Stack Overflow here on [how to order by categorical](https://stackoverflow.com/questions/56113231/how-to-sort-my-data-according-to-month-order-i-want-my-month-order-to-be-april).

# %%
months = ['OCT','NOV',
          'DEC','JAN','FEB','MAR',
        'APR','MAY','JUN','JUL','AUG', 'SEP']

# %%
df['Month'] = pd.CategoricalIndex(df['Month (abbv)'], ordered=True, categories=months)

# %%
# Make the state dataframe again because we've modified original df
dfs = df[df.State.isin(states)]

# %%
dfs.pivot_table(index=['Fiscal Year','Month'], columns='State', values='Encounter Count', aggfunc='sum') \
   .sort_values(by=['Fiscal Year','Month'])
# Out:
# State                 AZ     CA     NM      TX
# Fiscal Year Month
# 2020        OCT     8518   9903   1712   29399
#             NOV     8644   9679   1250   26953
#             DEC     8388   9969   1115   25320
#             JAN     6771   9828   1167   23119
#             FEB     7185  10317   1128   22151
#             MAR     6254  10598   1411   22723
#             APR     2991   5661   1137   15818
#             MAY     3922   7683   1974   18492
#             JUN     5851  10322   2792   22258
#             JUL     6530  12475   3717   23484
#             AUG     7656  13433   4749   30284
#             SEP     9315  12302   5859   36451
# 2021        OCT    12543  14151   6073   45709
#             NOV    13407  14438   5971   44388
#             DEC    12598  14387   7676   45393
#             JAN    12597  16143   6734   49855
#             FEB    20157  17292   7416   61576
#             MAR    32068  23718   9794  114184
#             APR    34423  26567  12214  112640
#             MAY    32773  27817  15302  111453
#             JUN    31858  27985  14544  121589
#             JUL    34067  28146  13240  145223
#             AUG    34992  26166  14127  141498
#             SEP    40573  23512  12539  122398
# 2022        OCT    41419  25578   9699   95822
#             NOV    45128  23986   9714  103457
#             DEC    46069  24978   9916  105705
#             JAN    42094  22607   9608   88789
#             FEB    42700  24271  10790   95926
#             MAR    58879  33306  13916  125564
#             APR    54892  46071  13947  128836
#             MAY    61385  34209  13003  141571
#             JUN    44605  29020  13789  129269
#             JUL    42123  31340  12847  120957
#             AUG    43825  31974  14429  123016
#             SEP    48601  34952  12199  140878
# 2023        OCT    49442  37797  10536  142636
#             NOV    49842  36713  10570  147541
#             DEC    54704  42669  10154  154913
#             JAN    33415  31304  16675   85118
#             FEB    35879  31071  20783   77412
#             MAR    49400  39489  25186   89012
#             APR    49511  40102  21160  110702
#             MAY    48186  39915  14489  114275
#             JUN    36259  30596  10354   76658
#             JUL    49203  34390   9971   98834
#             AUG    59589  39239  11759  132257
#             SEP    61471  47256   9215  161356
# 2024        OCT    65246  51516   8119  125862
#             NOV    74816  51515   8079  116664
#             DEC    91354  55774   8414  155737
#             JAN    58322  44250   8298   73750
#             FEB        0      0      0       0
#             MAR        0      0      0       0
#             APR        0      0      0       0
#             MAY        0      0      0       0
#             JUN        0      0      0       0
#             JUL        0      0      0       0
#             AUG        0      0      0       0
#             SEP        0      0      0       0

# %%
dfpiv = dfs.pivot_table(index=['Fiscal Year','Month'], columns='State', values='Encounter Count', aggfunc='sum') \
    .sort_values(by=['Fiscal Year','Month'])

# %%
# We just need to drop the last ones
# (Change this number each time for how many are blank)
dfpiv.drop(dfpiv.tail(8).index, inplace=True)

# %%
dfpiv.tail()
# Out:
# State                 AZ     CA    NM      TX
# Fiscal Year Month
# 2023        SEP    61471  47256  9215  161356
# 2024        OCT    65246  51516  8119  125862
#             NOV    74816  51515  8079  116664
#             DEC    91354  55774  8414  155737
#             JAN    58322  44250  8298   73750

# %%
dfpiv.plot(kind='line')
# Out:
# <Axes: xlabel='Fiscal Year,Month'>

# %% [markdown]
# That's better!

# %%
dfpiv.to_csv('data/Land-border-encounters-MAR24.csv')
